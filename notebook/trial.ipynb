# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')

# %%
print(data.head())
# Out:
#           x          y
# 0  0.000000   7.993428
# 1  0.204082   7.335716
# 2  0.408163   9.519867
# 3  0.612245  11.882794
# 4  0.816327   8.980673

# %%
plt.scatter(data.x, data.y)
plt.show()

# %%
def loss_func_mse(m, b, points):
    total_err = 0
    
    for i in range(len(points)):
        x1 = points.iloc[i].x
        y1 = points.iloc[i].y
        total_err += (y1 - (m * x1 + b)) ** 2
    
    total_err / float(len(points))

# %%
def gradient_descent(m_now, b_now, points, L):
    m_grad = 0
    b_grad  = 0
    n = len(points)
    
    for i in range(n):
        x1 = points.iloc[i].x
        y1 = points.iloc[i].y
        
        m_grad += -(2/n) * x1 * (y1 - (m_now * x1 + b_now))
        b_grad += -(2/n) * (y1 - (m_now * x1 + b_now))
        
    m = m_now - m_grad * L
    b = b_now - b_grad * L
    
    return m, b

# %%
m = 0
b = 0
L = 0.01
epochs = 100

for i in range(epochs):
    m, b = gradient_descent(m, b, data, L)

# %%
print(m, b)
# Out:
# 3.475349655171472 3.1763506658957192

# %%
plt.scatter(data.x, data.y, color = "black")
plt.plot(list(range(0, 10)), [m * x + b for  x in range(0, 10)])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
